# %% [markdown]
# # Funktioiden kuvaajien piirtäminen Pythonilla
#
# Python on hyvä työkalu funktioiden kuvaajien piirtämisen. Tarvitaan kirjastot `matplotlib`, sieltä varsinkin `pyplot`, isäksi `numpy`. Eli alla olevat määritykset pitää olla:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Lähtökohtaisesti määritellään x-akselin rajat ja montako yksikköä sille merkitään, y-akseli tulee sitten arvojen mukaan:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1, 3)
y = np.where((x >= 1) & (x <= 3), -2*x + 6, np.where((x >= -1) & (x <= 1), 4, np.nan))

plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Yksinkertaisimmillaan kuvaajan voi piirtää luomalla `x = np.linspace(a, b, n)` komennolla taulukkoon $n$ kappaletta $x$-muuttujan arvoja välillä $[a, b]$. Toiseen taulukkoon $y$ lasketaan niitä vastaavat funktion arvot. Kuvaaja piirretään komennolla `plt.plot(x, y)`.
#
# Allaolevilla komennoilla piirretään funktion
# $$f(x) = x^2$$
# kuvaaja välillä $[-2, 2]$.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-2, 2, 10)
y = x**2
plt.plot(x, y)
plt.show()

# %% [markdown]
# Kun yleensä piirretään kuvaajia koordinaatistoon, niin x- ja y-akselit ovat kuvan keskellä, voidaan käyttää subplot-ominaisuutta:

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-5, 5, 100)
y = x**2
z = 2*x-4

ax=plt.subplot()

ax.spines['left'].set_position(('data',0))
ax.spines['bottom'].set_position(('data',0))
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# samat mittasuhteet
ax.set_aspect('equal')

# x-akselin säätöä
ax.set_xticks(np.arange(-5, 5, 1))


# Y:lle rajat, että kuvaajat näkyvät fiksummin
plt.ylim([-7, 7])

# label tarvitsee tuon legend():n
plt.plot(x, y, label="$y = x^2$")
plt.plot(x, z, label="$y = 3x - 5$")
plt.legend()

plt.show()

# %% [markdown]
# Jos tuon ('data', 0) tilalle laittaa 'center', niin silloin origo lähtee seikkailemaan eikä pysy (0, 0):ssa. Alla vielä esimerkki, miten noita paloittain määriteltyjä kuvaajia voi määritellä.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-5, 5, 100)
y = (3/5)*x
x2=np.linspace(5, 15, 100)
y2=-(3/5)*x2+6

ax=plt.subplot()

ax.spines['left'].set_position(('data',0))
ax.spines['bottom'].set_position(('data',0))
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# samat mittasuhteet
ax.set_aspect('equal')
ax.set_ylim([-10, 10])

plt.plot(x, y, color='blue')
plt.plot(x2,y2, color='blue')

plt.show()

# %% [markdown]
# # Tehtävät
#
# 1. Kpl 5.3, teht. 8 s. 96: Piirrä funktion kuvaaja.
# 1. Samoin tehtävässä 9
# 1. Kpl 5.4 s 100: Tehtävästä 1 taitanee riittää kuvaajat kohdista a ja b
# 1. Ja lopuksi tehtävän 4 lentorataa kuvaava paraabeli.
